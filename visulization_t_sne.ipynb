# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from dtw import dtw, accelerated_dtw
from numpy.linalg import norm
from joblib import Parallel, delayed
import pickle
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.manifold import TSNE

# %%
# prepare data
X = pickle.load(open('auxiliaries/dwt_distance_full.pk','rb'))
Y = np.load('auxiliaries/labels.npy')

# %%
X.shape, Y.shape
# Out:
# ((1050, 1050), (1050,))

# %%
#X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=42, stratify=Y)

# %%
#X_train.shape

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2,perplexity=10, metric='precomputed').fit_transform(X)

fig, ax = plt.subplots()
ax.scatter(X_embedded[:, 0], X_embedded[:, 1], c=Y, cmap=plt.cm.Spectral)
plt.show()

# %%
fig, ax = plt.subplots()
ax.scatter(X_embedded[:, 0], X_embedded[:, 1], c=Y, cmap=plt.cm.Spectral)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-482fb2c75e34> in <module>
# ----> 1 fig, ax = plt.subplots()
#       2 #ax.scatter(X_embedded[:, 0], X_embedded[:, 1], c=Y, cmap=plt.cm.Spectral)
#       3 ax.scatter(*zip(*X_embedded[:,:2]), c=Y, cmap=plt.cm.Spectral)
#       4 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2,perplexity=20, metric='precomputed').fit_transform(X)

fig, ax = plt.subplots()
ax.scatter(X_embedded[:, 0], X_embedded[:, 1], c=Y, cmap=plt.cm.Spectral)
plt.show()

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=3,perplexity=30, metric='precomputed').fit_transform(X)

fig, ax = plt.subplots()
ax.scatter(X_embedded[:, 0], X_embedded[:, 1],X_embedded[:, 3], c=Y, cmap=plt.cm.Spectral)
plt.show()

# %%
from sklearn.manifold import TSNE
X_embedded = TSNE(n_components=2,perplexity=50, metric='precomputed').fit_transform(X)

fig, ax = plt.subplots()
ax.scatter(X_embedded[:, 0], X_embedded[:, 1], c=Y, cmap=plt.cm.Spectral)
plt.show()

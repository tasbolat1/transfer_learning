# %% [markdown]
# # SNN on BioTac Data
#
# Here we implement autoencoder:
#
# loss = loss_classification + loss_regression

# %%
import sys, os
CURRENT_TEST_DIR = os.getcwd()
sys.path.append(CURRENT_TEST_DIR + "/../../../slayerPytorch/src")

# %%
import slayerSNN as snn
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import norm
from joblib import Parallel, delayed
import torch
import copy
from torch.utils.data import Dataset
from sklearn.model_selection import train_test_split
from tas_utils import get_trainValLoader, get_testLoader

np.random.seed(1)
torch.manual_seed(1)

# %% [markdown]
# ### upload data

# %%
data_dir = '../../new_data_folder/'
logDir = 'models_and_stats/'
kfold_number = 0

model_name = 'semisupervised_bio_' + str(kfold_number)
screen_fr = 20

save_dir = logDir + model_name + '.pt'

train_loader, val_loader, train_dataset, val_dataset = get_trainValLoader(data_dir, k=0)
test_loader, test_dataset = get_testLoader(data_dir)

# %% [markdown]
# ### define spike neuron

# %%
params = {
    "neuron": {
        "type": "SRMALPHA",
        "theta": 5, # 10
        "tauSr": 10.0,
        "tauRef": 2.0,
        "scaleRef": 2,
        "tauRho": 1,
        "scaleRho": 1,
    },
    "simulation": {"Ts": 1.0, "tSample": 75, "nSample": 1},
    "training": {
        "error": {
            "type": "NumSpikes",  # "NumSpikes" or "ProbSpikes"
            "probSlidingWin": 20,  # only valid for ProbSpikes
            "tgtSpikeRegion": {  # valid for NumSpikes and ProbSpikes
                "start": 0,
                "stop": 75,
            },
            "tgtSpikeCount": {True: 60, False: 10},
        }
    },
}

params2 = {
    "neuron": {
        "type": "SRMALPHA",
        "theta": 5, # 10
        "tauSr": 10.0,
        "tauRef": 2.0,
        "scaleRef": 2,
        "tauRho": 1,
        "scaleRho": 1,
    },
    "simulation": {"Ts": 1.0, "tSample": 75, "nSample": 1},
    "training": {
        "error": {
            "type": "SpikeTime",  # "NumSpikes" or "ProbSpikes"
            "probSlidingWin": 20,  # only valid for ProbSpikes
            "tgtSpikeRegion": {  # valid for NumSpikes and ProbSpikes
                "start": 0,
                "stop": 75,
            },
            "tgtSpikeCount": {True: 60, False: 10},
        }
    },
}

# %%
class SlayerMLP(torch.nn.Module):
    def __init__(self, params, input_size, hidden_size1, hidden_size2, output_size):
        super(SlayerMLP, self).__init__()
        self.output_size = output_size
        self.slayer = snn.layer(params["neuron"], params["simulation"])
        self.fc1 = self.slayer.dense(input_size, hidden_size1)
        self.fc2 = self.slayer.dense(hidden_size1, hidden_size2)
        self.fc3 = self.slayer.dense(hidden_size2, output_size)
        
        self.fc_decoder1 = self.slayer.dense(hidden_size2, 30)
        self.fc_decoder2 = self.slayer.dense(30, input_size)

    def get_spike(self, inp):
        return self.slayer.spike(inp)
    
    def forward(self, spike_input):
        spike_1 = self.slayer.spike(self.slayer.psp(self.fc1(spike_input)))
        spike_2 = self.slayer.spike(self.slayer.psp(self.fc2(spike_1)))
        spike_output = self.slayer.spike(self.slayer.psp(self.fc3(spike_2)))
        
        spike_hat1 = self.slayer.spike(self.slayer.psp(self.fc_decoder1(spike_2)))
        spike_hat2 = self.slayer.spike(self.slayer.psp(self.fc_decoder2(spike_hat1)))
        
        return spike_output, spike_hat2, spike_2, spike_hat1

# %%
device = torch.device("cuda:1")
net = SlayerMLP(params, 19, 50, 50, 20).to(device)

# %%
error = snn.loss(params).to(device)
error2 = snn.loss(params2).to(device)
optimizer = torch.optim.RMSprop(net.parameters(), lr=0.00005, weight_decay=0.5)

# %%
# train_total_losses=[]
# train_class_losses=[]
# train_regres_losses=[]

# val_total_losses=[]
# val_class_losses=[]
# val_regres_losses=[]

# test_total_losses=[]
# test_class_losses=[]
# test_regres_losses=[]

# train_accs = []
# test_accs = []
# val_accs = []


# alpha = 1
# beta = 0.001

# max_val_acc = 0

for epoch in range(10001):
    net.train()
    correct = 0
    loss_train = 0
    loss_class = 0
    loss_reg = 0
    for i, (_, tact,  target, label) in enumerate(train_loader):
        
        tact = tact.to(device)
        tact = tact[...,::2]
        target = target.to(device)
        tact = net.get_spike(tact)
        
        output, out_input, _, _ = net.forward(tact)
        
        correct += torch.sum(snn.predict.getClass(output) == label).data.item()
        loss_class = error.numSpikes(output, target)
        
        loss_reg = error2.spikeTime(out_input, tact)
        
        loss = alpha*loss_class + beta*loss_reg
        
        loss_train += loss.item()
        loss_class += alpha*loss_class.item()
        loss_reg += beta*loss_reg.item()
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
                
    if epoch%screen_fr == 0:
        print('Epoch: ', epoch, ' --------------------------')
        print('Train loss (all, class, reg):', 
              loss_train/len(train_dataset),
              loss_class.item()/len(train_dataset),
              loss_reg.item()/len(train_dataset))
        print('Train accuracy:', correct/len(train_dataset))
    train_accs.append(correct/len(train_dataset))
    train_total_losses.append(loss_train/len(train_dataset))
    train_class_losses.append(loss_class.item()/len(train_dataset))
    train_regres_losses.append(loss_reg.item()/len(train_dataset))
    
    net.eval()
    correct = 0
    loss_val = 0
    loss_class = 0
    loss_reg = 0
    with torch.no_grad():
        for i, (_, tact, target, label) in enumerate(val_loader):

            tact = tact.to(device)
            tact = tact[...,::2]
            target = target.to(device)
            tact = net.get_spike(tact)
            output, out_input, _, _ = net.forward(tact)
        
            correct += torch.sum(snn.predict.getClass(output) == label).data.item()
            loss_class = error.numSpikes(output, target)

            loss_reg = error2.spikeTime(out_input, tact)

            loss = alpha*loss_class + beta*loss_reg

            loss_val += loss.item()
            loss_class += alpha*loss_class.item()
            loss_reg += beta*loss_reg.item()
            
    if epoch%screen_fr == 0:
        print('Val loss (all, class, reg):', 
              loss_val/len(val_dataset),
              loss_class.item()/len(val_dataset),
              loss_reg.item()/len(val_dataset))
        print('Val accuracy:', correct/len(val_dataset))
    val_accs.append(correct/len(val_dataset))
    val_total_losses.append(loss_val/len(val_dataset))
    val_class_losses.append(loss_class.item()/len(val_dataset))
    val_regres_losses.append(loss_reg.item()/len(val_dataset))
    
    if correct/len(val_dataset) >= max_val_acc:
        print('Saving model at ', epoch, ' epoch')
        max_val_acc = correct/len(val_dataset)
        torch.save(net.state_dict(), save_dir)
# Out:
# Epoch:  0  --------------------------
# Train loss (all, class, reg): 5.552066418329875 0.038111114501953126 46.620930989583336
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg):
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.965755290985108 0.4088666534423828 133.731171875
# Val accuracy: 0.93
# Epoch:  920  --------------------------
# Train loss (all, class, reg): 5.450998474756877 0.03648888905843099 40.401324869791665
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.957683238983154 0.3118000030517578 129.53201171875
# Val accuracy: 0.93
# Epoch:  940  --------------------------
# Train loss (all, class, reg): 5.451060829162597 0.07715555826822916 44.751640625
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.966005592346192 0.4336000061035156 148.653310546875
# Val accuracy: 0.93
# Epoch:  960  --------------------------
# Train loss (all, class, reg): 5.452372907002767 0.06471111297607422 73.43022135416666
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.9539406204223635 0.3035333251953125 119.80943359375
# Val accuracy: 0.925
# Epoch:  980  --------------------------
# Train loss (all, class, reg): 5.452691259384156 0.06888889312744141 47.958255208333334
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.958196086883545 0.34419998168945315 132.007275390625
# Val accuracy: 0.93
# Epoch:  1000  --------------------------
# Train loss (all, class, reg): 5.443779640197754 0.03437777837117513 49.34295572916667
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.960765075683594 0.2118000030517578 135.8027734375
# Val accuracy: 0.93
# Epoch:  1020  --------------------------
# Train loss (all, class, reg): 5.447875989278158 0.06942222595214843 41.9584375
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.940520362854004 0.25906667709350584 133.72943359375
# Val accuracy: 0.935
# Epoch:  1040  --------------------------
# Train loss (all, class, reg): 5.440764408111573 0.08355555852254232 37.49782552083333
# Train accuracy: 0.9833333333333333
# Val loss (all, class, reg): 6.942593898773193 0.13826666831970214 155.654697265625
# Val accuracy: 0.925
# Epoch:  1060  --------------------------
# Train loss (all, class, reg): 5.429510866800944 0.04388888676961263 52.30020833333333
# Train accuracy: 0.9883333333333333
# Val loss (all, class, reg): 6.9490241432189945 0.1468666648864746 119.460751953125
# Val accuracy: 0.935
# Epoch:  1080  --------------------------
# Train loss (all, class, reg): 5.430496892929077 0.07482222239176432 43.515690104166666
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.941647834777832 0.3411333465576172 108.362705078125
# Val accuracy: 0.94
# Epoch:  1100  --------------------------
# Train loss (all, class, reg): 5.438226731618245 0.0338444455464681 40.77267252604167
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.9369087982177735 0.17826667785644532 133.4711328125
# Val accuracy: 0.935
# Epoch:  1120  --------------------------
# Train loss (all, class, reg): 5.4378028424580895 0.053111114501953126 44.871067708333335
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.922341327667237 0.2732666778564453 138.111552734375
# Val accuracy: 0.93
# Epoch:  1140  --------------------------
# Train loss (all, class, reg): 5.424888235727946 0.05844444274902344 52.019951171875
# Train accuracy: 0.9883333333333333
# Val loss (all, class, reg): 6.954961776733398 0.48846668243408203 147.6841015625
# Val accuracy: 0.935
# Epoch:  1160  --------------------------
# Train loss (all, class, reg): 5.430193792978923 0.03351111094156901 52.6779296875
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.959314384460449 0.17026668548583984 180.06990234375
# Val accuracy: 0.93
# Epoch:  1180  --------------------------
# Train loss (all, class, reg): 5.432590847015381 0.05133333841959636 46.078837890625
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.9282581329345705 0.22073333740234374 116.720009765625
# Val accuracy: 0.93
# Epoch:  1200  --------------------------
# Train loss (all, class, reg): 5.423482125600179 0.06831111272176106 41.14016927083333
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.937271919250488 0.42540000915527343 146.152548828125
# Val accuracy: 0.925
# Epoch:  1220  --------------------------
# Train loss (all, class, reg): 5.412425746917725 0.038733332951863604 41.72171223958333
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.907624626159668 0.317933349609375 133.089189453125
# Val accuracy: 0.93
# Epoch:  1240  --------------------------
# Train loss (all, class, reg): 5.423388338088989 0.037000001271565754 42.651064453125
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.935769309997559 0.4981999969482422 131.412958984375
# Val accuracy: 0.925
# Epoch:  1260  --------------------------
# Train loss (all, class, reg): 5.429773022333781 0.021711111068725586 50.81572591145834
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.911216373443604 0.1383333396911621 148.885546875
# Val accuracy: 0.93
# Epoch:  1280  --------------------------
# Train loss (all, class, reg): 5.412939472198486 0.025111111005147298 47.3886328125
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.94580192565918 0.29293333053588866 139.401064453125
# Val accuracy: 0.92
# Epoch:  1300  --------------------------
# Train loss (all, class, reg): 5.415560131072998 0.05573333740234375 38.07923828125
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.925889167785645 0.4187333679199219 146.42892578125
# Val accuracy: 0.925
# Epoch:  1320  --------------------------
# Train loss (all, class, reg): 5.4186505063374835 0.04637777964274088 39.188486328125
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.917776565551758 0.1868000030517578 129.31259765625
# Val accuracy: 0.925
# Epoch:  1340  --------------------------
# Train loss (all, class, reg): 5.417128067016602 0.05351111094156901 49.19348307291666
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.892625560760498 0.23400001525878905 130.068427734375
# Val accuracy: 0.93
# Epoch:  1360  --------------------------
# Train loss (all, class, reg): 5.415842212041219 0.048288885752360025 42.28486328125
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.902664070129394 0.5515333557128906 126.282734375
# Val accuracy: 0.92
# Epoch:  1380  --------------------------
# Train loss (all, class, reg): 5.4252191797892255 0.0916888936360677 43.16348958333333
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.919916553497314 0.48506668090820315 134.446669921875
# Val accuracy: 0.925
# Epoch:  1400  --------------------------
# Train loss (all, class, reg): 5.42273331006368 0.05088888804117839 52.587998046875
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg): 6.9111690330505375 0.20953332901000976 129.66345703125
# Val accuracy: 0.92
# Epoch:  1420  --------------------------
# Train loss (all, class, reg): 5.4188152567545576 0.03531111399332682 46.83285481770833
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.922740039825439 0.26086666107177736 139.376640625
# Val accuracy: 0.925
# Epoch:  1440  --------------------------
# Train loss (all, class, reg): 5.433105017344157 0.03062222162882487 49.1636328125
# Train accuracy: 0.985
# Val loss (all, class, reg): 6.91091459274292 0.3168666839599609 152.163251953125
# Val accuracy: 0.93
# Epoch:  1460  --------------------------
# Train loss (all, class, reg): 5.424820130666097 0.04344444274902344 45.18248046875
# Train accuracy: 0.9866666666666667
# Val loss (all, class, reg):
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.568771591186524 0.32193328857421877 129.60294921875
# Val accuracy: 0.925
# Epoch:  9040  --------------------------
# Train loss (all, class, reg): 4.850607786178589 0.028400001525878907 50.151448567708336
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.5552473068237305 0.26906665802001956 115.39796875
# Val accuracy: 0.93
# Epoch:  9060  --------------------------
# Train loss (all, class, reg): 4.8456626256306965 0.027488889694213866 44.78697916666667
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.560091590881347 0.25786666870117186 116.44298828125
# Val accuracy: 0.925
# Epoch:  9080  --------------------------
# Train loss (all, class, reg): 4.842310940424602 0.057044448852539065 39.45829752604167
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.544605674743653 0.34333335876464843 119.240751953125
# Val accuracy: 0.925
# Epoch:  9100  --------------------------
# Train loss (all, class, reg): 4.84696122487386 0.020977776845296225 50.23822916666666
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.566088752746582 0.40299995422363283 135.561513671875
# Val accuracy: 0.925
# Epoch:  9120  --------------------------
# Train loss (all, class, reg): 4.84207457224528 0.05179999669392903 45.23636393229167
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.548473606109619 0.18233333587646483 122.3299609375
# Val accuracy: 0.925
# Epoch:  9140  --------------------------
# Train loss (all, class, reg): 4.837409861882528 0.02353333314259847 47.52045572916666
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.539093818664551 0.22493331909179687 134.543427734375
# Val accuracy: 0.925
# Epoch:  9160  --------------------------
# Train loss (all, class, reg): 4.844389743804932 0.057088890075683595 38.630078125
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.561210403442383 0.2788666534423828 132.465283203125
# Val accuracy: 0.925
# Epoch:  9180  --------------------------
# Train loss (all, class, reg): 4.839786469141642 0.026000000635782877 41.37441080729167
# Train accuracy: 0.9933333333333333
# Val loss (all, class, reg): 6.552845973968505 0.2104666519165039 158.1476171875
# Val accuracy: 0.925
# Epoch:  9200  --------------------------
# Train loss (all, class, reg): 4.836431411107381 0.03822222073872884 68.4533984375
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.544588603973389 0.1698666763305664 139.49591796875
# Val accuracy: 0.93
# Epoch:  9220  --------------------------
# Train loss (all, class, reg): 4.842494503657023 0.03931111335754395 43.26198567708333
# Train accuracy: 0.9933333333333333
# Val loss (all, class, reg): 6.5452907943725585 0.2615333557128906 98.78998046875
# Val accuracy: 0.93
# Epoch:  9240  --------------------------
# Train loss (all, class, reg): 4.845573555628459 0.04095555941263835 46.338922526041664
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.539023532867431 0.1021333408355713 143.156826171875
# Val accuracy: 0.925
# Epoch:  9260  --------------------------
# Train loss (all, class, reg): 4.846693989435832 0.04126666704813639 51.964908854166666
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.541317958831787 0.25733333587646484 145.739716796875
# Val accuracy: 0.925
# Epoch:  9280  --------------------------
# Train loss (all, class, reg): 4.832082846959432 0.03193333307902018 51.09876302083333
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.532418308258056 0.10193333625793458 121.72115234375
# Val accuracy: 0.925
# Epoch:  9300  --------------------------
# Train loss (all, class, reg): 4.829800564448039 0.03208889007568359 41.792001953125
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.5335383796691895 0.30599998474121093 132.120390625
# Val accuracy: 0.925
# Epoch:  9320  --------------------------
# Train loss (all, class, reg): 4.832625449498495 0.055933329264322915 37.920556640625
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.538990287780762 0.32093330383300783 143.531708984375
# Val accuracy: 0.925
# Epoch:  9340  --------------------------
# Train loss (all, class, reg): 4.8354196357727055 0.061288884480794274 46.69930989583333
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.536462421417236 0.31466663360595704 135.039453125
# Val accuracy: 0.925
# Epoch:  9360  --------------------------
# Train loss (all, class, reg): 4.826539923350016 0.022711111704508465 42.28798828125
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.537322483062744 0.11813333511352539 131.2863671875
# Val accuracy: 0.925
# Epoch:  9380  --------------------------
# Train loss (all, class, reg): 4.8184894212086995 0.039977776209513344 43.11608072916667
# Train accuracy: 0.9933333333333333
# Val loss (all, class, reg): 6.5441481590271 0.1184000015258789 148.790126953125
# Val accuracy: 0.925
# Epoch:  9400  --------------------------
# Train loss (all, class, reg): 4.8316261704762775 0.03837778091430664 47.86751953125
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.5230451011657715 0.19600000381469726 134.87626953125
# Val accuracy: 0.925
# Epoch:  9420  --------------------------
# Train loss (all, class, reg): 4.811618887583415 0.0358222230275472 41.852275390625
# Train accuracy: 0.9933333333333333
# Val loss (all, class, reg): 6.5022422981262205 0.15940000534057616 125.5955859375
# Val accuracy: 0.925
# Epoch:  9440  --------------------------
# Train loss (all, class, reg): 4.828044856389363 0.01904444376627604 46.25753255208333
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.530738887786865 0.19253334045410156 130.420078125
# Val accuracy: 0.93
# Epoch:  9460  --------------------------
# Train loss (all, class, reg): 4.817772356669108 0.025600001017252603 42.279378255208336
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.509206123352051 0.13079999923706054 152.647548828125
# Val accuracy: 0.93
# Epoch:  9480  --------------------------
# Train loss (all, class, reg): 4.815432430903117 0.021933333079020182 40.82899739583333
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.527645645141601 0.14940000534057618 111.945087890625
# Val accuracy: 0.925
# Epoch:  9500  --------------------------
# Train loss (all, class, reg): 4.82636339823405 0.058822218577067056 40.29821614583334
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.53143159866333 0.11793333053588867 124.394326171875
# Val accuracy: 0.935
# Epoch:  9520  --------------------------
# Train loss (all, class, reg): 4.817220859527588 0.019711111386617023 77.5459375
# Train accuracy: 0.9933333333333333
# Val loss (all, class, reg): 6.495446014404297 0.24559999465942384 143.220888671875
# Val accuracy: 0.93
# Epoch:  9540  --------------------------
# Train loss (all, class, reg): 4.81744662920634 0.02740000089009603 51.43766927083333
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.4953008651733395 0.3199333190917969 119.998427734375
# Val accuracy: 0.935
# Epoch:  9560  --------------------------
# Train loss (all, class, reg): 4.809159901936849 0.02286666711171468 40.38873372395833
# Train accuracy: 0.99
# Val loss (all, class, reg): 6
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.464967994689942 0.07539999961853028 131.3859765625
# Val accuracy: 0.935
# Epoch:  9860  --------------------------
# Train loss (all, class, reg): 4.807842400868734 0.018288888931274415 44.96707682291667
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.47921667098999 0.18053333282470704 122.74748046875
# Val accuracy: 0.935
# Epoch:  9880  --------------------------
# Train loss (all, class, reg): 4.798110990524292 0.03364444732666016 47.985325520833335
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.447497310638428 0.2935333251953125 139.680458984375
# Val accuracy: 0.935
# Epoch:  9900  --------------------------
# Train loss (all, class, reg): 4.800130472183228 0.036000003814697264 54.73326171875
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.451010894775391 0.11673334121704101 129.985771484375
# Val accuracy: 0.935
# Epoch:  9920  --------------------------
# Train loss (all, class, reg): 4.79896650314331 0.01580000082651774 45.77962565104167
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.448499507904053 0.22586666107177733 127.516357421875
# Val accuracy: 0.93
# Epoch:  9940  --------------------------
# Train loss (all, class, reg): 4.803127110799154 0.029044443766276042 45.192408854166665
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.480136432647705 0.3369333267211914 120.948037109375
# Val accuracy: 0.93
# Epoch:  9960  --------------------------
# Train loss (all, class, reg): 4.80831919670105 0.027333335876464845 40.18998697916667
# Train accuracy: 0.9916666666666667
# Val loss (all, class, reg): 6.464036140441895 0.31799999237060544 146.113701171875
# Val accuracy: 0.93
# Epoch:  9980  --------------------------
# Train loss (all, class, reg): 4.804818731943766 0.02144444465637207 43.643203125
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.443147974014282 0.1562666702270508 151.862041015625
# Val accuracy: 0.94
# Epoch:  10000  --------------------------
# Train loss (all, class, reg): 4.791376113891602 0.044866663614908854 43.934912109375
# Train accuracy: 0.99
# Val loss (all, class, reg): 6.469232521057129 0.14026666641235352 152.285732421875
# Val accuracy: 0.93

# %%
# save stats
import pickle
all_stats = [
    train_total_losses,
    train_class_losses,
    train_regres_losses,
    val_total_losses,
    val_class_losses,
    val_regres_losses,
    train_accs,
    val_accs
]

pickle.dump(all_stats, open(logDir + model_name + '_stats.pkl', 'wb'))

# %%
fig, ax = plt.subplots(4, figsize=(15,15))

ax[0].set_title('Total loss')
ax[0].plot(train_total_losses)
ax[0].plot(val_total_losses)
ax[0].set_ylabel('Loss')
ax[0].legend(['Train', 'Validation'])

ax[1].set_title('Reconstruction loss')
ax[1].plot(train_regres_losses)
ax[1].plot(val_regres_losses)
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Validation'])

ax[2].set_title('Classification loss')
ax[2].plot(train_class_losses)
ax[2].plot(val_class_losses)
ax[2].set_ylabel('Loss')
ax[2].legend(['Train', 'Validation'])

ax[3].set_title('Accuracy')
ax[3].plot(train_accs)
ax[3].plot(val_accs)
ax[3].set_xlabel('Epoch')
ax[3].set_ylabel('Accuracy')
ax[3].legend(['Train', 'Validation'])

plt.show()

# %%
# testing set check
net_trained = SlayerMLP(params, 19, 50, 50, 20).to(device)
net_trained.load_state_dict(torch.load(save_dir))
net_trained.eval()
# Out:
# SlayerMLP(
#   (slayer): spikeLayer()
#   (fc1): _denseLayer(19, 50, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (fc2): _denseLayer(50, 50, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (fc3): _denseLayer(50, 20, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (fc_decoder1): _denseLayer(50, 30, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#   (fc_decoder2): _denseLayer(30, 19, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
# )

# %%
correct = 0
loss_test = 0
with torch.no_grad():
    for i, (_, tact, target, label) in enumerate(test_loader):

        tact = tact.to(device)
        tact = tact[...,::2]
        target = target.to(device)
        
        tact = net.get_spike(tact)
        
        output, _, _, _ = net_trained.forward(tact)

        correct += torch.sum(snn.predict.getClass(output) == label).data.item()

# %%
print(correct/len(test_loader.dataset))
# Out:
# 0.93

# %% [markdown]
# ### visualize latent representation

# %%
from sklearn.manifold import TSNE

# %%
def get_metrics(lloader, _net):
    # Draw representations
    _net.eval()
    big_list = []
    label_list=[]
    with torch.no_grad():
        for i, (_, tact, target, label) in enumerate(lloader):

            tact = tact.to(device)
            tact = tact[...,::2]
            target = target.to(device)
            tact = net.get_spike(tact)
            _, _, rep, _ = _net.forward(tact)
            big_list.append(rep)
            label_list.append(label)

    test_representation = torch.cat(big_list,0)
    label_all = torch.cat(label_list, 0)
    label_all = label_all.cpu().numpy()
    dist_mat = torch.zeros([len(lloader.dataset),len(lloader.dataset)])
    for i in range(len(lloader.dataset)):
        for j in range(len(lloader.dataset)):
            if i == j:
                dist_mat[i, j] = 0.0
            else:
                dist_mat[i,j] = error2.spikeTime(test_representation[i], test_representation[j])

    dist_mat = dist_mat.detach().cpu().numpy()
    
    return dist_mat, label_all

# %%
# test
dist_mat, label_all = get_metrics(test_loader, net_trained)

# %%
tsne_model = TSNE(n_components=2,perplexity=30, metric='precomputed')

# %%
X_embedded = tsne_model.fit_transform(dist_mat)

# %%
fig, ax = plt.subplots()
ax.scatter(X_embedded[:, 0], X_embedded[:, 1], c=label_all, cmap=plt.cm.Spectral)
plt.show()

# %%
# train
dist_mat, label_all = get_metrics(train_loader, net_trained)

# %%
X_embedded = tsne_model.fit_transform(dist_mat)

# %%
fig, ax = plt.subplots()
ax.scatter(X_embedded[:, 0], X_embedded[:, 1], c=label_all, cmap=plt.cm.Spectral)
plt.show()

# %%
# confusion matrix

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn

# %%
with torch.no_grad():
    for i, (_, tact, target, label) in enumerate(test_loader):

        tact = tact.to(device)
        tact = tact[...,::2]
        target = target.to(device)
        
        tact = net.get_spike(tact)
        
        output, _, _, _ = net_trained.forward(tact)

        pred_label = snn.predict.getClass(output) == label

# %%
count = 0
testing_true = torch.zeros([len(train_loader.dataset),2])
with torch.no_grad():
    for i, (tact_icub, tact_bio,  target, label) in enumerate(train_loader, 0):
        testing_true[count:count+label.shape[0],0] = label

        # Forward pass of the network.
        tact_bio = tact_bio.to(device)
        tact_bio = tact_bio[...,::2]
        print(tact_bio.shape)
        output, _, rep_out_bio, _ = net_trained.forward(tact_bio)
        predicted_label = snn.predict.getClass(output)

        testing_true[count:count+label.shape[0],1] = predicted_label
        count += label.shape[0]
cm = confusion_matrix(testing_true[:,0].numpy(), testing_true[:,1].numpy())
plt.figure(figsize = (10,7))
plt.tight_layout(True)
sn.heatmap(cm, annot=True)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()
# Out:
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
# torch.Size([8, 19, 1, 1, 75])
